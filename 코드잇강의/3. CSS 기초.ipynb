# %% [markdown]
# ## 웹페이지 스타일링 원리
# * CSS를 사용하면 HTML태그에 색, 폰트, 크기, 여백 등을 설정 할 수 있다.
# * CSS 코드는 'HTML 태그를 선택하는 코드'(CSS selector)와
#     '스타일을 지정하는 코드'로 구성
# >```CSS
# >
# >li {
# >  color: blue;
# >  font-size: 20px;
# >}
# >```
#
#  ```li``` : 모든 \<li\>태그를 대상으로 스타일을 적용하라
#
#  ```{color: blue;}``` : 색상을 파란색(blue)으로 바꾸라
#
#  ```{font-size: 20px;}``` : 글자 크기를 20px으로
#
#  -> "모든 li 태그의 색깔은 파란색으로, 크기는 20px로 하라"

# %% [markdown]
# ### CSS선택자 1. 태그이름
# CSS 선택자로 '태그의 이름'을 쓰면, 그 태그 모두에 스타일이 입혀진다.
# ![image.png](attachment:bf50f9bd-e91c-4ec5-bc37-604c924431f1.png)

# %% [markdown]
# ### CSS선택자 2. 아이디(id)
# * 태그 전체가 아닌, 태그 내에 단 하나의 값에만 스타일을 입히고 싶다면, 태그안에 id 속성을 지정하고 해당 id에만 스타일을 적용할 수 있다.
#
# * 동일한 id를 여러 태그가 가질 수 없다. id는 고유해야 함.
# ```html
# <li id="coffee">커피</li>
# <li id="green-tea">녹차</li>
# <li id="milk">우유</li>
# ```
# ```css
# #green-tea {
#   color: blue;
#   font-size: 20px;
# }
# ```
#
# ![image.png](attachment:634a5c8c-6611-45b9-9477-02942f526e12.png)

# %% [markdown]
# ### CSS선택자3. 클래스(Class)
# * 여러 태그에 동시에 스타일을 입히고 싶을 때, HTML 태그에 Class란 속성에 적용한다.
# *
# ```html
# <li class="favorite">커피</li>
# <li>녹차</li>
# <li class="favorite">우유</li>
#
# ```
#
# ```css
# .favorite {
#   color: blue;
#   font-
#     size: 20px;
# }
#
# ```
#
# ![image.png](attachment:09e54232-552e-4d01-8eff-0381806f1349.png)

# %% [markdown]
# ### CSS선택자 4. 속성(attribute)
# * id와 class 외 기타 속성도 CSS 선택자로 사용 할 수 있다.
# * id, class는 css선택자로 워낙 많이 사용하여 '#'이나 '.'처럼 쉽게 사용하는 문법이 별도로 있는 것.
# * 기타 속성은 ```[name="value"]```와 같이 속성이름과 속성 값을 CSS선택자로 활용할 수 있다.
# ```css
# [alt="green-tea"] {
#   width: 300px;
# }
# ```
# :  "alt 속성의 값이 "green-tea"인 태그의 가로 길이를 300px로 하라"

# %% [markdown]
# ### CSS Reference
# https://www.w3schools.com/cssref/

# %%
import pandas as pd
table = pd.read_html("https://www.w3schools.com/cssref/")
len(table)
# Out:
# 23

# %%
for i in range(23):
    display(table[i])
# Out:
#                             0  \
# 0               align-content
# 1                 align-items
# 2                  align-self
# 3                         all
# 4                   animation
# 5             animation-delay
# 6         animation-direction
# 7          animation-duration
# 8         animation-fill-mode
# 9   animation-iteration-count
# 10             animation-name
# 11       animation-play-state
# 12  animation-timing-function
#
#                                                     1
# 0   Specifies the alignment between the lines insi...
# 1   Specifies the alignment for items inside a fle...
# 2   Specifies the alignment for selected items ins...
# 3   Resets all properties (except unicode-bidi and...
# 4   A shorthand property for all the animation-* p...
# 5     Specifies a delay for the start of an animation
# 6   Specifies whether an animation should be playe...
# 7   Specifies how long an animation should take to...
# 8   Specifies a style for the element when the ani...
# 9   Specifies the number of times an animation sho...
# 10      Specifies a name for the @keyframes animation
# 11  Specifies whether the animation is running or ...
# 12          Specifies the speed curve of an animation
#                              0  \
# 0          backface-visibility
# 1                   background
# 2        background-attachment
# 3        background-blend-mode
# 4              background-clip
# 5             background-color
# 6             background-image
# 7            background-origin
# 8          background-position
# 9            background-repeat
# 10             background-size
# 11                      border
# 12               border-bottom
# 13         border-bottom-color
# 14   border-bottom-left-radius
# 15  border-bottom-right-radius
# 16         border-bottom-style
# 17         border-bottom-width
# 18             border-collapse
# 19                border-color
# 20                border-image
# 21         border-image-outset
# 22         border-image-repeat
# 23          border-image-slice
# 24         border-image-source
# 25          border-image-width
# 26                 border-left
# 27           border-left-color
# 28           border-left-style
# 29           border-left-width
# 30               border-radius
# 31                border-right
# 32          border-right-color
# 33          border-right-style
# 34          border-right-width
# 35              border-spacing
# 36                border-style
# 37                  border-top
# 38            border-top-color
# 39      border-top-left-radius
# 40     border-top-right-radius
# 41            border-top-style
# 42            border-top-width
# 43                border-width
# 44                      bottom
# 45        box-decoration-break
# 46                  box-shadow
# 47                  box-sizing
# 48                 break-after
# 49                break-before
# 50                break-inside
#
#                                                     1
# 0   Defines whether or not the back face of an ele...
# 1   A shorthand property for all the background-* ...
# 2   Sets whether a background image scrolls with t...
# 3   Specifies the blending mode of each background...
# 4   Defines how far the background (color or image...
# 5        Specifies the background color of an element
# 6   Specifies one or more background images for an...
# 7   Specifies the origin position of a background ...
# 8        Specifies the position of a background image
# 9     Sets if/how a background image will be repeated
# 10        Specifies the size of the background images
# 11  A shorthand property for border-width, border-...
# 12  A shorthand property for border-bottom-width, ...
# 13                Sets the color of the bottom border
# 14  Defines the radius of the border of the bottom...
# 15  Defines the radius of the border of the bottom...
# 16                Sets the style of the bottom border
# 17                Sets the width of the bottom border
# 18  Sets whether table borders should collapse int...
# 19                 Sets the color of the four borders
# 20  A shorthand property for all the border-image-...
# 21  Specifies the amount by which the border image...
# 22  Specifies whether the border image should be r...
# 23            Specifies how to slice the border image
# 24  Specifies the path to the image to be used as ...
# 25            Specifies the width of the border image
# 26  A shorthand property for all the border-left-*...
# 27                  Sets the color of the left border
# 28                  Sets the style of the left border
# 29                  Sets the width of the left border
# 30  A shorthand property for the four border-*-rad...
# 31  A shorthand property for all the border-right-...
# 32                 Sets the color of the right border
# 33                 Sets the style of the right border
# 34                 Sets the width of the right border
# 35  Sets the distance between the borders of adjac...
# 36                 Sets the style of the four borders
# 37  A shorthand property for border-top-width, bor...
# 38                   Sets the color of the top border
# 39  Defines the radius of the border of the top-le...
# 40  Defines the radius of the border of the top-ri...
# 41                   Sets the style of the top border
# 42                   Sets the width of the top border
# 43                 Sets the width of the four borders
# 44  Sets the elements position, from the bottom of...
# 45  Sets the behavior of the background and border...
# 46         Attaches one or more shadows to an element
# 47  Defines how the width and height of an element...
# 48  Specifies whether or not a page-, column-, or ...
# 49  Specifies whether or not a page-, column-, or ...
# 50  Specifies whether or not a page-, column-, or ...
#                     0                                                  1
# 0        caption-side         Specifies the placement of a table caption
# 1         caret-color  Specifies the color of the cursor (caret) in i...
# 2            @charset  Specifies the character encoding used in the s...
# 3               clear  Specifies on which sides of an element floatin...
# 4                clip             Clips an absolutely positioned element
# 5               color                             Sets the color of text
# 6        column-count  Specifies the number of columns an element sho...
# 7         column-fill     Specifies how to fill columns, balanced or not
# 8          column-gap              Specifies the gap between the columns
# 9         column-rule  A shorthand property for all the column-rule-*...
# 10  column-rule-color    Specifies the color of the rule between columns
# 11  column-rule-style    Specifies the style of the rule between columns
# 12  column-rule-width    Specifies the width of the rule between columns
# 13        column-span  Specifies how many columns an element should s...
# 14       column-width                         Specifies the column width
# 15            columns  A shorthand property for column-width and colu...
# 16            content  Used with the :before and :after pseudo-elemen...
# 17  counter-increment  Increases or decreases the value of one or mor...
# 18      counter-reset         Creates or resets one or more CSS counters
# 19             cursor  Specifies the mouse cursor to be displayed whe...
#            0                                                  1
# 0  direction     Specifies the text direction/writing direction
# 1    display  Specifies how a certain HTML element should be...
#              0                                                  1
# 0  empty-cells  Specifies whether or not to display borders an...
#                           0                                                  1
# 0                    filter  Defines effects (e.g. blurring or color shifti...
# 1                      flex  A shorthand property for the flex-grow, flex-s...
# 2                flex-basis    Specifies the initial length of a flexible item
# 3            flex-direction      Specifies the direction of the flexible items
# 4                 flex-flow  A shorthand property for the flex-direction an...
# 5                 flex-grow  Specifies how much the item will grow relative...
# 6               flex-shrink  Specifies how the item will shrink relative to...
# 7                 flex-wrap  Specifies whether the flexible items should wr...
# 8                     float        Specifies whether or not a box should float
# 9                      font  A shorthand property for the font-style, font-...
# 10               @font-face  A rule that allows websites to download and us...
# 11              font-family                 Specifies the font family for text
# 12    font-feature-settings  Allows control over advanced typographic featu...
# 13     @font-feature-values  Allows authors to use a common name in font-va...
# 14             font-kerning  Controls the usage of the kerning information ...
# 15   font-language-override  Controls the usage of language-specific glyphs...
# 16                font-size                    Specifies the font size of text
# 17         font-size-adjust  Preserves the readability of text when font fa...
# 18             font-stretch  Selects a normal, condensed, or expanded face ...
# 19               font-style                  Specifies the font style for text
# 20           font-synthesis  Controls which missing typefaces (bold or ital...
# 21             font-variant  Specifies whether or not a text should be disp...
# 22  font-variant-alternates  Controls the usage of alternate glyphs associa...
# 23        font-variant-caps  Controls the usage of alternate glyphs for cap...
# 24  font-variant-east-asian  Controls the usage of alternate glyphs for Eas...
# 25   font-variant-ligatures  Controls which ligatures and contextual forms ...
# 26     font-variant-numeric  Controls the usage of alternate glyphs for num...
# 27    font-variant-position  Controls the usage of alternate glyphs of smal...
# 28              font-weight                     Specifies the weight of a font
#                         0                                                  1
# 0                     gap  A shorthand property for the row-gap and the c...
# 1                    grid  A shorthand property for the grid-template-row...
# 2               grid-area  Either specifies a name for the grid item, or ...
# 3       grid-auto-columns                    Specifies a default column size
# 4          grid-auto-flow  Specifies how auto-placed items are inserted i...
# 5          grid-auto-rows                       Specifies a default row size
# 6             grid-column  A shorthand property for the grid-column-start...
# 7         grid-column-end               Specifies where to end the grid item
# 8         grid-column-gap      Specifies the size of the gap between columns
# 9       grid-column-start             Specifies where to start the grid item
# 10               grid-gap  A shorthand property for the grid-row-gap and ...
# 11               grid-row  A shorthand property for the grid-row-start an...
# 12           grid-row-end               Specifies where to end the grid item
# 13           grid-row-gap         Specifies the size of the gap between rows
# 14         grid-row-start             Specifies where to start the grid item
# 15          grid-template  A shorthand property for the grid-template-row...
# 16    grid-template-areas  Specifies how to display columns and rows, usi...
# 17  grid-template-columns  Specifies the size of the columns, and how man...
# 18     grid-template-rows    Specifies the size of the rows in a grid layout
#                      0                                                  1
# 0  hanging-punctuation  Specifies whether a punctuation character may ...
# 1               height                      Sets the height of an element
# 2              hyphens  Sets how to split words to improve the layout ...
#                  0                                                  1
# 0  image-rendering  Gives a hint to the browser about what aspects...
# 1          @import  Allows you to import a style sheet into anothe...
# 2        isolation  Defines whether an element must create a new s...
#                  0                                                  1
# 0  justify-content  Specifies the alignment between the items insi...
#             0                             1
# 0  @keyframes  Specifies the animation code
#                      0                                                  1
# 0                 left  Specifies the left position of a positioned el...
# 1       letter-spacing  Increases or decreases the space between chara...
# 2           line-break                    Specifies how/if to break lines
# 3          line-height                               Sets the line height
# 4           list-style  Sets all the properties for a list in one decl...
# 5     list-style-image         Specifies an image as the list-item marker
# 6  list-style-position  Specifies the position of the list-item marker...
# 7      list-style-type             Specifies the type of list-item marker
#                  0                                                  1
# 0           margin  Sets all the margin properties in one declaration
# 1    margin-bottom               Sets the bottom margin of an element
# 2      margin-left                 Sets the left margin of an element
# 3     margin-right                Sets the right margin of an element
# 4       margin-top                  Sets the top margin of an element
# 5             mask  Hides an element by masking or clipping the im...
# 6        mask-type  Specifies whether a mask element is used as a ...
# 7       max-height              Sets the maximum height of an element
# 8        max-width               Sets the maximum width of an element
# 9           @media  Sets the style rules for different media types...
# 10      min-height              Sets the minimum height of an element
# 11       min-width               Sets the minimum width of an element
# 12  mix-blend-mode  Specifies how an element's content should blen...
#                   0                                                  1
# 0        object-fit  Specifies how the contents of a replaced eleme...
# 1   object-position  Specifies the alignment of the replaced elemen...
# 2           opacity              Sets the opacity level for an element
# 3             order  Sets the order of the flexible item, relative ...
# 4           orphans  Sets the minimum number of lines that must be ...
# 5           outline  A shorthand property for the outline-width, ou...
# 6     outline-color                       Sets the color of an outline
# 7    outline-offset  Offsets an outline, and draws it beyond the bo...
# 8     outline-style                       Sets the style of an outline
# 9     outline-width                       Sets the width of an outline
# 10         overflow  Specifies what happens if content overflows an...
# 11    overflow-wrap  Specifies whether or not the browser may break...
# 12       overflow-x  Specifies whether or not to clip the left/righ...
# 13       overflow-y  Specifies whether or not to clip the top/botto...
#                      0                                                  1
# 0              padding  A shorthand property for all the padding-* pro...
# 1       padding-bottom              Sets the bottom padding of an element
# 2         padding-left                Sets the left padding of an element
# 3        padding-right               Sets the right padding of an element
# 4          padding-top                 Sets the top padding of an element
# 5     page-break-after      Sets the page-break behavior after an element
# 6    page-break-before     Sets the page-break behavior before an element
# 7    page-break-inside     Sets the page-break behavior inside an element
# 8          perspective     Gives a 3D-positioned element some perspective
# 9   perspective-origin  Defines at which position the user is looking ...
# 10      pointer-events  Defines whether or not an element reacts to po...
# 11            position  Specifies the type of positioning method used ...
#         0                                                  1
# 0  quotes  Sets the type of quotation marks for embedded ...
#          0                                                  1
# 0   resize  Defines if (and how) an element is resizable b...
# 1    right  Specifies the right position of a positioned e...
# 2  row-gap            Specifies the gap between the grid rows
#                  0                                                  1
# 0  scroll-behavior  Specifies whether to smoothly animate the scro...
#                              0  \
# 0                     tab-size
# 1                 table-layout
# 2                   text-align
# 3              text-align-last
# 4         text-combine-upright
# 5              text-decoration
# 6        text-decoration-color
# 7         text-decoration-line
# 8        text-decoration-style
# 9                  text-indent
# 10                text-justify
# 11            text-orientation
# 12               text-overflow
# 13                 text-shadow
# 14              text-transform
# 15     text-underline-position
# 16                         top
# 17                   transform
# 18            transform-origin
# 19             transform-style
# 20                  transition
# 21            transition-delay
# 22         transition-duration
# 23         transition-property
# 24  transition-timing-function
#
#                                                     1
# 0              Specifies the width of a tab character
# 1   Defines the algorithm used to lay out table ce...
# 2          Specifies the horizontal alignment of text
# 3   Describes how the last line of a block or a li...
# 4   Specifies the combination of multiple characte...
# 5              Specifies the decoration added to text
# 6          Specifies the color of the text-decoration
# 7     Specifies the type of line in a text-decoration
# 8   Specifies the style of the line in a text deco...
# 9   Specifies the indentation of the first line in...
# 10  Specifies the justification method used when t...
# 11      Defines the orientation of the text in a line
# 12  Specifies what should happen when text overflo...
# 13                                Adds shadow to text
# 14                Controls the capitalization of text
# 15  Specifies the position of the underline which ...
# 16  Specifies the top position of a positioned ele...
# 17    Applies a 2D or 3D transformation to an element
# 18  Allows you to change the position on transform...
# 19  Specifies how nested elements are rendered in ...
# 20  A shorthand property for all the transition-* ...
# 21    Specifies when the transition effect will start
# 22  Specifies how many seconds or milliseconds a t...
# 23  Specifies the name of the CSS property the tra...
# 24  Specifies the speed curve of the transition ef...
#               0                                                  1
# 0  unicode-bidi  Used together with the direction property to s...
# 1   user-select  Specifies whether the text of an element can b...
#                 0                                               1
# 0  vertical-align       Sets the vertical alignment of an element
# 1      visibility  Specifies whether or not an element is visible
#               0                                                  1
# 0   white-space  Specifies how white-space inside an element is...
# 1        widows  Sets the minimum number of lines that must be ...
# 2         width                       Sets the width of an element
# 3    word-break  Specifies how words should break when reaching...
# 4  word-spacing  Increases or decreases the space between words...
# 5     word-wrap  Allows long, unbreakable words to be broken an...
# 6  writing-mode  Specifies whether lines of text are laid out h...
#          0                                             1
# 0  z-index  Sets the stack order of a positioned element
